# %%
# %load_ext autoreload
# %autoreload 2
import tools
# Out:
# HF_HOME:  /nfs/roberts/scratch/pi_vsb4/byh2/huggingface

# %%
tools.get_pymatgen_docs("Structure")
# Out:
# {'success': False,
#  'stderr': "No pymatgen entry found matching 'Structure'",
#  'suggestions': ['set_structure',
#   'get_structure',
#   'set_structures',
#   'get_structures',
#   'structure_graph']}
