# %%
import aiida
from aiida.orm import Group

# %%
aiida.load_profile()
# Out:
# Profile<uuid='9dbeaf0c640743f19d68f2c37a6b1374' name='presto'>

# %%
from aiida import load_profile
load_profile()

from aiida.orm import Group

group = next(g for g in Group.collection.all() if len(g.nodes) > 0)

elements = sorted(p.element for p in group.nodes)

print(len(elements))
print(elements)
# Out:
# 72
# ['Ag', 'Al', 'Ar', 'As', 'Au', 'B', 'Ba', 'Be', 'Bi', 'Br', 'C', 'Ca', 'Cd', 'Cl', 'Co', 'Cr', 'Cs', 'Cu', 'F', 'Fe', 'Ga', 'Ge', 'H', 'He', 'Hf', 'Hg', 'I', 'In', 'Ir', 'K', 'Kr', 'La', 'Li', 'Lu', 'Mg', 'Mn', 'Mo', 'N', 'Na', 'Nb', 'Ne', 'Ni', 'O', 'Os', 'P', 'Pb', 'Pd', 'Po', 'Pt', 'Rb', 'Re', 'Rh', 'Rn', 'Ru', 'S', 'Sb', 'Sc', 'Se', 'Si', 'Sn', 'Sr', 'Ta', 'Tc', 'Te', 'Ti', 'Tl', 'V', 'W', 'Xe', 'Y', 'Zn', 'Zr']
